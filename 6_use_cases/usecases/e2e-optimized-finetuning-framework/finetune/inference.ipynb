# %%
from inference import predict_batch

# %%
prompt = ["net_usage_actual_revenue_latest_month | +12.4B && net_usage_actual_revenue_mom | 165.4K && net_usage_actual_revenue_mom_pct | 0.9% && net_usage_top_n_movers | Moaybe Inc. (+$22.9K or 19.3%), Udbnjybyg Inc. (+$96.5K or 51.9%), M (+$48.3K or 27.1%) && net_usage_bottom_n_movers | Nspkrtvl Ocinpjle (-$21.3K or 21.5%), Ayeuwzkwa Inc. (-$15.7K or 73.5%), Ffiywi Gosl (-$7174 or 77.7%)"]
endpoint = "flan-t5-large-ia3-2025-11-23-07-01-45-294-endpoint"

# %%
results = predict_batch(prompt, endpoint)

# %%
results
# Out:
# '+2.4B (+$22.9K or 19.3%), Udbnjybyg Inc. (+$96.5K or 51.9%), M (+$48.3K or 27.1%) && net_usage_bottom_n_movers was Nspkrtvl Ocinpjle (-$21.3K or 21.5%), Ayeuwzkwa Inc. (-$15.7K or 73.5%), Ffiywi Gosl (-$7174 or 77.7%).'
