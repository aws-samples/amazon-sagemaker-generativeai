# %% [markdown]
# # GR00T N1.7 — Step 1: Data Preparation
#
# This notebook downloads BridgeData V2 from HuggingFace, generates 7-DoF actions via optical flow,
# saves intermediate episode folders (like the OpenVLA pipeline), converts to LeRobot V2 format,
# validates the dataset, and uploads to S3 for the SageMaker training job.
#
# **Pipeline:**
# 1. Download BridgeData V2 → save episode folders (images, actions.npy, language.txt)
# 2. Validate intermediate dataset (check for NaN, shape, missing files)
# 3. Convert episode folders → LeRobot V2 format (parquet + MP4 + metadata)
# 4. Upload to S3
#
# **Runtime:** ~30-45 min for 600 episodes

# %% [markdown]
# ## 1. Environment Setup

# %%
# Install dependencies (run once)
# %pip install -Uq datasets==4.8.4 pyarrow==23.0.1 opencv-python-headless==4.13.0.92 Pillow==12.2.0 numpy==2.4.4 tqdm==4.67.3 sagemaker==3.8.0 boto3==1.42.93
# Out:
# Requirement already satisfied: datasets in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (4.8.4)
# Requirement already satisfied: pyarrow in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (23.0.1)
# Requirement already satisfied: opencv-python-headless in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: Pillow in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (12.2.0)
# Requirement already satisfied: numpy in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (2.4.4)
# Requirement already satisfied: tqdm in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (4.67.3)
# Requirement already satisfied: sagemaker in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (3.8.0)
# Requirement already satisfied: boto3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (1.42.93)
# Requirement already satisfied: filelock in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (3.29.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (2.33.1)
# Requirement already satisfied: httpx<1.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (1.11.0)
# Requirement already satisfied: packaging in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.13)
# Requirement already satisfied: h11>=0.16 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.4.3)
# Requirement already satisfied: typer in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: sagemaker-core<3.0.0,>=2.8.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker) (2.8.0)
# Requirement already satisfied: sagemaker-train<2.0.0,>=1.8.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker) (1.8.0)
# Requirement already satisfied: sagemaker-serve<2.0.0,>=1.8.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker) (1.8.0)
# Requirement already satisfied: sagemaker-mlops<2.0.0,>=1.8.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker) (1.8.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (2.13.3)
# Requirement already satisfied: jsonschema<5.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (4.26.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (4.9.6)
# Requirement already satisfied: rich<15.0.0,>=13.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (14.3.4)
# Requirement already satisfied: mock<5.0,>4.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (4.0.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (6.11.0)
# Requirement already satisfied: pytz>=2021.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (2026.1.post1)
# Requirement already satisfied: attrs>=20.3.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (26.1.0)
# Requirement already satisfied: protobuf<7.0.0,>=3.12 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (6.33.6)
# Requirement already satisfied: smdebug_rulesconfig>=1.0.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (1.0.1)
# Requirement already satisfied: schema>=0.7.5 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (0.7.8)
# Requirement already satisfied: omegaconf>=2.1.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (2.3.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (1.17.1)
# Requirement already satisfied: cloudpickle>=2.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (3.1.2)
# Requirement already satisfied: paramiko>=2.11.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (4.0.0)
# Requirement already satisfied: tblib>=1.7.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (3.2.2)
# Requirement already satisfied: cryptography>=46.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-core<3.0.0,>=2.8.0->sagemaker) (46.0.7)
# Requirement already satisfied: botocore<1.43.0,>=1.42.93 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from boto3) (1.42.93)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from boto3) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from boto3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.93->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.93->boto3) (2.6.3)
# Requirement already satisfied: zipp>=0.5 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (3.23.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (0.30.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (2.46.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.93->boto3) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from rich<15.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (2.20.0)
# Requirement already satisfied: pyiceberg>=0.8.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.8.0->sagemaker) (0.11.1)
# Requirement already satisfied: s3fs in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-mlops<2.0.0,>=1.8.0->sagemaker) (0.4.2)
# Requirement already satisfied: deepdiff in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (9.0.0)
# Requirement already satisfied: mlflow in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.11.1)
# Requirement already satisfied: sagemaker_schema_inference_artifacts in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.0.5)
# Requirement already satisfied: pytest in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (9.0.3)
# Requirement already satisfied: psutil in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (7.2.2)
# Requirement already satisfied: tritonclient[http] in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.67.0)
# Requirement already satisfied: onnx in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.21.0)
# Requirement already satisfied: onnxruntime in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.25.0)
# Requirement already satisfied: torch>=2.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.11.0)
# Requirement already satisfied: graphene<4,>=3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.8.0->sagemaker) (3.4.3)
# Requirement already satisfied: jinja2<4.0,>=3.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.8.0->sagemaker) (3.1.6)
# Requirement already satisfied: sagemaker-mlflow<1.0.0,>=0.0.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.8.0->sagemaker) (0.3.0)
# Requirement already satisfied: nest_asyncio>=1.5.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker-train<2.0.0,>=1.8.0->sagemaker) (1.6.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.8.0->sagemaker) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0,>=1.8.0->sagemaker) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from jinja2<4.0,>=3.0->sagemaker-train<2.0.0,>=1.8.0->sagemaker) (3.0.3)
# Requirement already satisfied: mlflow-skinny==3.11.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.11.1)
# Requirement already satisfied: mlflow-tracing==3.11.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.11.1)
# Requirement already satisfied: Flask-CORS<7 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (6.0.2)
# Requirement already satisfied: Flask<4 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.1.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.18.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (7.1.0)
# Requirement already satisfied: gunicorn<26 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (25.3.0)
# Requirement already satisfied: huey<3,>=2.5.4 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.10.8)
# Requirement already satisfied: scikit-learn<2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.8.0)
# Requirement already satisfied: skops<1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.0.49)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (8.3.3)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.103.0)
# Requirement already satisfied: fastapi<1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.136.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.1.47)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.41.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.41.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.41.0)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.2.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.5.5)
# Requirement already satisfied: uvicorn<1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.45.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: Mako in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.3.11)
# Requirement already satisfied: cffi>=2.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cryptography>=46.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.49.2)
# Requirement already satisfied: starlette>=0.46.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.1.8)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.3.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.62b0)
# Requirement already satisfied: tzdata>=2022.7 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pandas->datasets) (2026.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from skops<1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.17.0)
# Requirement already satisfied: greenlet>=1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.4.0)
# Requirement already satisfied: pycparser in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=46.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (0.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from omegaconf>=2.1.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (4.9.3)
# Requirement already satisfied: bcrypt>=3.2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (5.0.0)
# Requirement already satisfied: invoke>=2.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (3.0.3)
# Requirement already satisfied: pynacl>=1.5 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from paramiko>=2.11.0->sagemaker-core<3.0.0,>=2.8.0->sagemaker) (1.6.2)
# Requirement already satisfied: wcwidth in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from prettytable>=3.9->skops<1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.6.3)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.8.0->sagemaker) (5.2.1)
# Requirement already satisfied: strictyaml<2.0.0,>=1.7.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.8.0->sagemaker) (1.7.3)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.8.0->sagemaker) (9.1.4)
# Requirement already satisfied: pyroaring<2.0.0,>=1.0.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.8.0->sagemaker) (1.0.4)
# Requirement already satisfied: zstandard<1.0.0,>=0.13.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pyiceberg>=0.8.0->pyiceberg[glue]>=0.8.0->sagemaker-mlops<2.0.0,>=1.8.0->sagemaker) (0.25.0)
# Requirement already satisfied: setuptools<82 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.6.1)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.5.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.0.0->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.3.0)
# Requirement already satisfied: orderly-set<6,>=5.5.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from deepdiff->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (5.5.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from onnx->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.5.4)
# Requirement already satisfied: flatbuffers in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from onnxruntime->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (25.12.19)
# Requirement already satisfied: iniconfig>=1.0.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pytest->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from pytest->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.6.0)
# Requirement already satisfied: json5>=0.9.22 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from sagemaker_schema_inference_artifacts->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (0.14.0)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.23)
# Requirement already satisfied: geventhttpclient>=2.3.3 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (2.3.9)
# Requirement already satisfied: gevent in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (26.4.0)
# Requirement already satisfied: brotli in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (1.2.0)
# Requirement already satisfied: zope.event in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (6.1)
# Requirement already satisfied: zope.interface in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0,>=1.8.0->sagemaker) (8.3)
# Requirement already satisfied: shellingham>=1.3.0 in /home/sagemaker-user/.conda/envs/groot/lib/python3.12/site-packages (from typer->huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Authentication Setup
#
# Configure Hugging Face authentication to access the BridgeData V2 dataset.

# %%
from getpass import getpass
from huggingface_hub import login

# Prompt for Hugging Face token (input is hidden)
hf_token = getpass("Enter your Hugging Face token: ")
login(token=hf_token)

# %%
import os
import json
import subprocess
import tempfile
from pathlib import Path

import boto3
import cv2
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import sagemaker
from datasets import load_dataset
from PIL import Image
from tqdm import tqdm

# %% [markdown]
# ## 2. Configuration
#
# ### SageMaker Session
#
# Initialize SageMaker session for S3 access.
#
# **IAM Permissions:** The SageMaker execution role should follow the principle of least privilege. At minimum, it needs:
# - `s3:GetObject` and `s3:PutObject` scoped to the specific training data and output bucket paths
# - `sagemaker:CreateTrainingJob` for launching training jobs

# %%
from sagemaker.core.helper import session_helper

sagemaker_session = session_helper.Session()
region = sagemaker_session.boto_region_name
account_id = boto3.client("sts").get_caller_identity()["Account"]
bucket_name = sagemaker_session.default_bucket()
default_prefix = sagemaker_session.default_bucket_prefix

print(f"Region: {region}")
print(f"Account: {account_id}")
print(f"Bucket: {bucket_name}")
print(f"Default prefix: {default_prefix}")

# %%
# Dataset parameters
MAX_EPISODES = 600          # Number of training episodes (use 10 for quick test)
ACTION_DIM = 7              # 7-DoF: x, y, z, roll, pitch, yaw, gripper

# Local paths
RAW_DATASET_DIR = "./bridge_synthetic_dataset"   # Intermediate episode folders
LEROBOT_DATASET_DIR = "./datasets/bridge_lerobot" # Final LeRobot V2 format

# S3 configuration
if default_prefix:
    S3_PREFIX = f"{default_prefix}/groot-finetuning/datasets/bridge_lerobot"
else:
    S3_PREFIX = "groot-finetuning/datasets/bridge_lerobot"

print(f"Episodes: {MAX_EPISODES}")
print(f"Raw dataset: {RAW_DATASET_DIR}")
print(f"LeRobot dataset: {LEROBOT_DATASET_DIR}")
print(f"S3 destination: s3://{bucket_name}/{S3_PREFIX}")

# %% [markdown]
# ## 3. Download BridgeData & Generate Actions (Optical Flow)
#
# This step downloads `VyoJ/BridgeData-V2-Scripted-Images` from HuggingFace and saves each episode
# as a folder with images, actions (via optical flow), and language instruction.
#
# This follows the same pattern as the OpenVLA pipeline (`fix_synthetic_dataset_fast.py`).

# %%
def estimate_actions_from_optical_flow(frames, action_dim=7):
    """
    Estimate 7-DoF actions from optical flow between consecutive frames.
    Returns actions of shape (T, action_dim).
    """
    actions = []
    for i in range(len(frames) - 1):
        img1 = np.array(frames[i].convert("RGB"))
        img2 = np.array(frames[i + 1].convert("RGB"))
        gray1 = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
        gray2 = cv2.cvtColor(img2, cv2.COLOR_RGB2GRAY)
        flow = cv2.calcOpticalFlowFarneback(
            gray1, gray2, None,
            pyr_scale=0.5, levels=3, winsize=15,
            iterations=3, poly_n=5, poly_sigma=1.2, flags=0,
        )
        mean_flow = np.mean(flow, axis=(0, 1))
        action = np.zeros(action_dim, dtype=np.float32)
        action[0] = mean_flow[0] / 100.0  # dx
        action[1] = mean_flow[1] / 100.0  # dy
        # dz, roll, pitch, yaw, gripper = 0 (can't infer from 2D)
        actions.append(action)
    # Final "stop" action
    actions.append(np.zeros(action_dim, dtype=np.float32))
    return np.array(actions, dtype=np.float32)

# %%
print("=== Downloading BridgeData V2 Scripted Images ===")
ds = load_dataset("VyoJ/BridgeData-V2-Scripted-Images")
data = ds["train"]
num_episodes = min(len(data), MAX_EPISODES)
print(f"Source: {len(data)} episodes, using {num_episodes}")

os.makedirs(RAW_DATASET_DIR, exist_ok=True)

print(f"\n=== Generating episode folders ===")
for idx in tqdm(range(num_episodes), desc="Generating"):
    sample = data[idx]
    episode_dir = os.path.join(RAW_DATASET_DIR, f"episode_{idx:06d}")
    os.makedirs(os.path.join(episode_dir, "images"), exist_ok=True)

    # Save images
    frames = [sample["first_image"], sample["intermediate_image"], sample["frame_43_image"]]
    frames = [f for f in frames if f is not None]
    for t, img in enumerate(frames):
        img.save(os.path.join(episode_dir, "images", f"{t:06d}.jpg"))

    # Generate actions via optical flow
    instruction = "move object to target"
    actions = estimate_actions_from_optical_flow(frames, ACTION_DIM)

    # Validate before saving
    if actions is None or actions.size == 0:
        actions = np.zeros((len(frames), ACTION_DIM), dtype=np.float32)
    if np.any(np.isnan(actions)) or np.any(np.isinf(actions)):
        actions = np.nan_to_num(actions, nan=0.0, posinf=0.0, neginf=0.0)

    # Save actions, language, metadata
    np.save(os.path.join(episode_dir, "actions.npy"), actions)
    with open(os.path.join(episode_dir, "language.txt"), "w") as f:
        f.write(instruction)
    with open(os.path.join(episode_dir, "metadata.json"), "w") as f:
        json.dump({"length": len(frames), "method": "optical_flow"}, f)

print(f"\nRaw dataset saved to: {RAW_DATASET_DIR}")
print(f"Episodes: {num_episodes}")

# %% [markdown]
# ## 4. Validate Intermediate Dataset
#
# Check all episodes for valid actions (no NaN, correct shape, no missing files).
# Same validation pattern as `check_synthetic_dataset.py` from the OpenVLA pipeline.

# %%
episodes = sorted([d for d in os.listdir(RAW_DATASET_DIR)
                   if os.path.isdir(os.path.join(RAW_DATASET_DIR, d))
                   and d.startswith("episode_")])

valid_count = 0
invalid_count = 0
missing_count = 0

for ep_name in episodes:
    ep_path = os.path.join(RAW_DATASET_DIR, ep_name)
    actions_file = os.path.join(ep_path, "actions.npy")

    if not os.path.exists(actions_file):
        missing_count += 1
        continue

    try:
        actions = np.load(actions_file, allow_pickle=True)
        if actions.dtype == object:
            actions = np.array(actions.tolist(), dtype=np.float32)

        has_images = len([f for f in os.listdir(os.path.join(ep_path, "images"))
                         if f.endswith((".jpg", ".png"))]) > 0
        has_lang = os.path.exists(os.path.join(ep_path, "language.txt"))
        no_nan = not np.any(np.isnan(actions)) and not np.any(np.isinf(actions))

        if has_images and has_lang and no_nan and actions.shape[1] == 7:
            valid_count += 1
        else:
            invalid_count += 1
    except:
        invalid_count += 1

print(f"Total episodes: {len(episodes)}")
print(f"✅ Valid: {valid_count} ({100*valid_count/len(episodes):.1f}%)")
print(f"⚠️  Invalid: {invalid_count}")
print(f"❌ Missing: {missing_count}")

if valid_count == len(episodes):
    print("\n✅ All episodes have valid actions! Ready to convert.")
else:
    print(f"\n⚠️  {invalid_count + missing_count} episodes have issues.")

# %%
# Show a sample episode
sample_ep = os.path.join(RAW_DATASET_DIR, episodes[0])
actions = np.load(os.path.join(sample_ep, "actions.npy"))
with open(os.path.join(sample_ep, "language.txt")) as f:
    lang = f.read().strip()
images = sorted([f for f in os.listdir(os.path.join(sample_ep, "images")) if f.endswith(".jpg")])

print(f"Sample episode: {episodes[0]}")
print(f"  Images: {len(images)} files")
print(f"  Actions shape: {actions.shape}")
print(f"  Actions:\n{actions}")
print(f"  Min: {np.min(actions):.6f}, Max: {np.max(actions):.6f}")
print(f"  Language: '{lang}'")

# %% [markdown]
# ## 5. Convert to LeRobot V2 Format
#
# Convert the validated episode folders to LeRobot V2 format (parquet + MP4 + metadata).
# This is the format GR00T N1.7 expects for fine-tuning.

# %%
TARGET_FRAMES = 30  # Frames per episode after interpolation
FPS = 5

def interpolate_frames(frames, target_count=30):
    """Interpolate between frames to create a longer episode via linear blending."""
    if len(frames) >= target_count:
        return frames[:target_count]
    result = []
    n_orig = len(frames)
    for i in range(target_count):
        src_pos = i * (n_orig - 1) / (target_count - 1)
        src_idx = int(src_pos)
        frac = src_pos - src_idx
        if src_idx >= n_orig - 1:
            result.append(frames[-1])
        elif frac < 0.01:
            result.append(frames[src_idx])
        else:
            img1 = np.array(frames[src_idx].convert("RGB"), dtype=np.float32)
            img2 = np.array(frames[src_idx + 1].convert("RGB"), dtype=np.float32)
            blended = ((1 - frac) * img1 + frac * img2).astype(np.uint8)
            result.append(Image.fromarray(blended))
    return result

def images_to_video(images, output_path, fps=5):
    """Convert a list of PIL images to an MP4 video using ffmpeg."""
    with tempfile.TemporaryDirectory() as tmpdir:
        for i, img in enumerate(images):
            if not isinstance(img, Image.Image):
                img = Image.fromarray(np.array(img))
            img.save(os.path.join(tmpdir, f"frame_{i:06d}.png"))
        cmd = [
            "ffmpeg", "-y", "-framerate", str(fps),
            "-i", os.path.join(tmpdir, "frame_%06d.png"),
            "-c:v", "libx264", "-pix_fmt", "yuv420p",
            "-crf", "23", "-preset", "fast", output_path,
        ]
        subprocess.run(cmd, capture_output=True, check=True)

# %%
# Create LeRobot V2 output dirs
output_path = Path(LEROBOT_DATASET_DIR)
data_dir = output_path / "data" / "chunk-000"
video_dir = output_path / "videos" / "chunk-000" / "observation.images.front"
meta_dir = output_path / "meta"
for d in [data_dir, video_dir, meta_dir]:
    d.mkdir(parents=True, exist_ok=True)

episodes_meta = []
tasks_set = {}
total_frames = 0
skipped = 0
all_actions, all_states, all_timestamps = [], [], []

print("=== Converting episode folders to LeRobot V2 ===")
for ep_idx, ep_name in enumerate(tqdm(episodes, desc="Converting")):
    ep_path = os.path.join(RAW_DATASET_DIR, ep_name)

    # Load images from episode folder
    image_dir = os.path.join(ep_path, "images")
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith((".jpg", ".png"))])
    frames = [Image.open(os.path.join(image_dir, f)) for f in image_files]

    if len(frames) < 2:
        skipped += 1
        continue

    # Interpolate to 30 frames (GR00T needs >= 16 for action horizon)
    frames = interpolate_frames(frames, target_count=TARGET_FRAMES)
    num_frames = len(frames)

    # Re-generate actions for interpolated frames (optical flow on 30 frames, not 3)
    actions = estimate_actions_from_optical_flow(frames, ACTION_DIM)
    states = actions.copy()  # pseudo-state (no proprioceptive state in this dataset)

    # Load language
    with open(os.path.join(ep_path, "language.txt")) as f:
        instruction = f.read().strip()
    if instruction not in tasks_set:
        tasks_set[instruction] = len(tasks_set)
    task_index = tasks_set[instruction]

    # Collect for stats
    all_actions.extend(actions.tolist())
    all_states.extend(states.tolist())
    all_timestamps.extend([fi / FPS for fi in range(num_frames)])

    # Write parquet
    rows = []
    for fi in range(num_frames):
        rows.append({
            "observation.state": states[fi].tolist(),
            "action": actions[fi].tolist(),
            "episode_index": ep_idx, "frame_index": fi,
            "index": total_frames + fi, "task_index": task_index,
            "timestamp": fi / FPS,
        })
    pq.write_table(pa.Table.from_pylist(rows), data_dir / f"episode_{ep_idx:06d}.parquet")

    # Write video
    try:
        images_to_video(frames, str(video_dir / f"episode_{ep_idx:06d}.mp4"), fps=FPS)
    except Exception as e:
        print(f"Warning: Video failed for episode {ep_idx}: {e}")
        skipped += 1
        continue

    episodes_meta.append({"episode_index": ep_idx, "tasks": [instruction], "length": num_frames})
    total_frames += num_frames

print(f"\nConverted {len(episodes_meta)} episodes ({skipped} skipped), {total_frames} total frames")

# %% [markdown]
# ## 6. Write LeRobot V2 Metadata

# %%
# info.json
info = {
    "codebase_version": "v2.1", "robot_type": "bridge_v2",
    "total_episodes": len(episodes_meta), "total_frames": total_frames,
    "total_tasks": len(tasks_set), "chunks_size": 1000, "fps": FPS,
    "splits": {"train": f"0:{len(episodes_meta)}"},
    "data_path": "data/chunk-{episode_chunk:03d}/episode_{episode_index:06d}.parquet",
    "video_path": "videos/chunk-{episode_chunk:03d}/{video_key}/episode_{episode_index:06d}.mp4",
    "features": {
        "action": {"dtype": "float32", "shape": [7], "names": ["x","y","z","roll","pitch","yaw","gripper"]},
        "observation.state": {"dtype": "float32", "shape": [7], "names": ["x","y","z","roll","pitch","yaw","gripper"]},
        "observation.images.front": {
            "dtype": "video", "shape": [480,640,3], "names": ["height","width","channels"],
            "info": {"video.height":480,"video.width":640,"video.codec":"av1","video.pix_fmt":"yuv420p",
                     "video.is_depth_map":False,"video.fps":FPS,"video.channels":3,"has_audio":False},
        },
        "timestamp": {"dtype":"float32","shape":[1],"names":None},
        "frame_index": {"dtype":"int64","shape":[1],"names":None},
        "episode_index": {"dtype":"int64","shape":[1],"names":None},
        "index": {"dtype":"int64","shape":[1],"names":None},
        "task_index": {"dtype":"int64","shape":[1],"names":None},
    },
    "total_chunks": 1, "total_videos": len(episodes_meta),
}
with open(meta_dir / "info.json", "w") as f:
    json.dump(info, f, indent=2)

# episodes.jsonl
with open(meta_dir / "episodes.jsonl", "w") as f:
    for ep in episodes_meta:
        f.write(json.dumps(ep) + "\n")

# tasks.jsonl
with open(meta_dir / "tasks.jsonl", "w") as f:
    for task_text, task_idx in sorted(tasks_set.items(), key=lambda x: x[1]):
        f.write(json.dumps({"task_index": task_idx, "task": task_text}) + "\n")

# modality.json
modality = {
    "video": {"front": {"original_key": "observation.images.front"}},
    "state": {"arm": {"start": 0, "end": 7}},
    "action": {"arm": {"start": 0, "end": 7}},
    "annotation": {"human.task_description": {"original_key": "task_index"}},
}
with open(meta_dir / "modality.json", "w") as f:
    json.dump(modality, f, indent=2)

# stats.json
all_actions_np = np.array(all_actions, dtype=np.float32)
all_states_np = np.array(all_states, dtype=np.float32)
all_timestamps_np = np.array(all_timestamps, dtype=np.float32).reshape(-1, 1)

def compute_stats(arr):
    return {
        "mean": np.mean(arr, axis=0).tolist(), "std": np.std(arr, axis=0).tolist(),
        "min": np.min(arr, axis=0).tolist(), "max": np.max(arr, axis=0).tolist(),
        "q01": np.percentile(arr, 1, axis=0).tolist(), "q99": np.percentile(arr, 99, axis=0).tolist(),
    }

stats = {
    "action": compute_stats(all_actions_np),
    "observation.state": compute_stats(all_states_np),
    "timestamp": compute_stats(all_timestamps_np),
}
with open(meta_dir / "stats.json", "w") as f:
    json.dump(stats, f, indent=2)

print(f"LeRobot V2 dataset saved to {LEROBOT_DATASET_DIR}")
print(f"  Episodes: {len(episodes_meta)}")
print(f"  Total frames: {total_frames}")

# %% [markdown]
# ## 7. Upload Dataset to S3

# %%
s3_client = boto3.client("s3")
local_root = Path(LEROBOT_DATASET_DIR)

files = [f for f in local_root.rglob("*") if f.is_file()]
print(f"Uploading {len(files)} files to s3://{bucket_name}/{S3_PREFIX}/")

# Note: The SageMaker default bucket has server-side encryption (SSE-S3) enabled by default.
# For custom buckets, enable server-side encryption with ExtraArgs={'ServerSideEncryption': 'aws:kms'}
for f in tqdm(files, desc="Uploading to S3"):
    relative = f.relative_to(local_root)
    s3_key = f"{S3_PREFIX}/{relative}"
    s3_client.upload_file(str(f), bucket_name, s3_key)

print(f"\nDataset uploaded to: s3://{bucket_name}/{S3_PREFIX}/")
print("You can now run the training notebook (02_training_job.ipynb)")
